# %% [markdown]
# # EXPLANATION
# ## CLEANING THE DATA
# As usual, cleaning the data was an integral part of <b>Advent of Code</b> challanges.<br /><br />
# In this case <code>cleaning_data(<i>item</i>)</code> will do those jobs of cleaning. Basically, this function will combine the raw data into a list via <code>.splitlines()</code> method.
#
# After that, we will create a <code>function</code> and start cleaning. So what will this function do, really?
# <ul>
#     <li>This function aiming to sort the data into <code>dictionary</code> inside a <code>list</code></li>
#     <li>To do that, you need to first declare an empty <code>list</code>, and empty <code>dictionary</code>--but the dictionary need to be inside <code>for</code> loop because we need it to encapsule every set of items inside the list, while we need the list to wrap ALL of the items.</li>
#     <li>Utilize <code>for</code> loop after that to go through all the items, and <code>.split()</code> the value of each item into two values</li>
#     <li>Let's begin to assign value into the dictionary! We will call the <code>keys</code> as <code>code</code> and the value to which those keys will be assigned to as <code>operand</code>. The value of keys <code>code</code>--based on the data structure, will be an index number <code>[0]</code> and the values of value <code>operand</code> will be an index number <code>[1]</code>. Don't forget to convert the <code>operand</code> into <code>int</code></li>
#     <li>Lastly, append the newly created dictionary into an empty list <code>list_operator</code> using <code>.append()</code> method, and return it so we can call it outside the function</li>
# </ul>
#
# ## PART 1 SOLUTION
# ### ITEM TO DESCRIBE
# To count the value of <code>accelerator</code>, there are several things we need to describe first at the beginning of the function. What is it?
# <ul>
#     <li>The length of the operation, described by <code>program_length</code></li>
#     <li>Index number of the current instruction, described by <code>program_counter</code></li>
#     <li>Total accumulator's value for the entire loop, described by <code>accumulator</code></li>
#     <li>Set of executed instruction, described by <code>executed_instruction</code> with data type od <code>set()</code>, and later it will store the <code>program_counter</code> value, think of it like it store an ID of each instruction.</li>
#     <li>A mark that will stop the loop before it go for a second time, described by <code>repeat</code> and the value set to <code>False</code>. It will set to <code>True</code> when the loop about to repeat.</li>
# </ul>
#
# ### MAIN FUNCTION
# Set of methods that will count the value of <code>accelerator</code>. Let's take a look what inside it!
# <ul>
#     <li>First, a <code>while</code> was needed to make sure it went through each index. The low limit will be set to zero while the upper limit would be set to the length of the operation. In the middle of it was out index of current operator, which is <code>program_counter</code></li>
#     <li>We then need to declare current items that will be executed, we get the index from <code>program_counter</code>, now we will assign those value into new variable that we will call <code>current_instruction</code>, it will take a function's argument with <code>current_instruction</code> inside brackets.</li>
#     <li>The first <code>if</code> was to check whether the instruction already been executed. If it already been executed, it will change <code>repeat</code> into True and end the loop. If it hasn't been executed, it will keep the loop.<li>
#     <li>Second <code>if</code> is for each condition that the instruction's <code>code</code> have. It will govern what to do when the method looped through certain <code>code</code> as per instructions. What I found in this case, when the <code>if current_instruction['code']</code> is True</li>-- the method immediatedly knows that the <code>current_instruction['operand']</code> mean the value of current <code>[code]</code> where the condition was True.
#         <ul>
#             <li>if the <code>code</code> is <code>jmp</code>, the program will skip certain number of index, depending on the value. if the value is <code>+4</code> then it will skip to four index after current operation.</li>
#             <li>if the <code>code</code> is <code>acc</code>, the program will take its value and add it into <code>accumulator</code>, ultimately will sum up all the <code>accumulator</code> value that the loop went through.</li>
#             <li>if the <code>code</code> is <code>nop</code>, it will just pass through</li>
#         </ul>
#     <li>Lastly, the <code>program_counter += 1</code> was there to make sure <code>while</code> loop won't looping endlessly</li>
# </ul>

# %%
with open('day8-list.txt', 'r') as file:
    content = file.read().splitlines()
    
def cleaning_data(item):
    list_operator = []
    for i in item:
        dict_operator = {}
        operator = i.split()
        dict_operator['code'] = operator[0]
        dict_operator['operand'] = int(operator[1])
        list_operator.append(dict_operator)
    return list_operator
list_of_instructions = cleaning_data(content)

#Part 1
def first_accumulator(instruction):
    program_length = len(instruction)
    program_counter = 0
    accumulator = 0
    executed_instructions = set()
    repeat = False
    
    while 0 <= program_counter < program_length:
        current_instruction = instruction[program_counter]
        
        if program_counter in executed_instructions:
            repeat = True
            break
        else:
            executed_instructions.add(program_counter)
            
        if current_instruction['code'] == 'jmp':
            program_counter += current_instruction['operand']
            continue
        elif current_instruction['code'] == 'acc':
            accumulator += current_instruction['operand']
        elif current_instruction['code'] == 'nop':
            pass
        else:
            print('Something went wrong in first_accumulator()')
            print(f'pc = {program_counter}, acc = {accumulator}')
            print(f'instruction:\n{instruction}')
        program_counter += 1
        
    if repeat:
        print(f'The accumulator at the first repeated instruction was {accumulator}')
    else:
        print('Reached the end of instruction without repeating')
            
first_accumulator(list_of_instructions)

#Part 2
def accumulator_halt_at_first_loop(instruction, switch_code = -1):
    program_length = len(instruction)
    program_counter = 0
    accumulator = 0
    executed_instruction = set()
    
    while 0 <= program_counter < program_length:
        current_instruction = instruction[program_counter]
        if program_counter in executed_instruction:
            return {
                'halted': False,
                'program_counter': program_counter,
                'accumulator': accumulator,
            }
        else:
            executed_instruction.add(program_counter)
            
        code = current_instruction['code']
        operand = current_instruction['operand']
        if program_counter == switch_code:
            print(f'Changing code at address {program_counter}')
            if code == 'jmp':
                print('- Changing jmp to nop')
                code = 'nop'
            elif code == 'nop':
                print('- Changin nop to jmp')
                code = 'jmp'
        if code == 'jmp':
            program_counter += operand
            continue
        elif code == 'acc':
            accumulator += operand
        elif code == 'nop':
            pass
        else:
            print('Something went wrong in accumulaor_halt_at_first_loop()')
            print(f'pc = {program_counter} acc = {accumulator}')
            print(f'instruction:\n{instruction}')
        program_counter += 1
    return {
        'halted': True,
        'program_counter': program_counter,
        'accumulator': accumulator,
    }

def run_instruction_with_mods(program):
    for index in range(len(program)):
        instruction = program[index]
        if instruction['code'] != 'acc':
            print(f'Found jmp or nop at address: {index}')
            result = accumulator_halt_at_first_loop(program, index)
            
            if result['halted']:
                print(f'Found it! {result}')
                break
            else:
                print('Not the correct instruction.')
run_instruction_with_mods(list_of_instructions)
# Out:
# The accumulator at the first repeated instruction was 1801
# Found jmp or nop at address: 2
# Changing code at address 2
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 3
# Changing code at address 3
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 7
# Not the correct instruction.
# Found jmp or nop at address: 10
# Changing code at address 10
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 12
# Not the correct instruction.
# Found jmp or nop at address: 14
# Changing code at address 14
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 15
# Not the correct instruction.
# Found jmp or nop at address: 19
# Not the correct instruction.
# Found jmp or nop at address: 20
# Changing code at address 20
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 21
# Changing code at address 21
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 22
# Not the correct instruction.
# Found jmp or nop at address: 24
# Not the correct instruction.
# Found jmp or nop at address: 27
# Not the correct instruction.
# Found jmp or nop at address: 31
# Not the correct instruction.
# Found jmp or nop at address: 36
# Changing code at address 36
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 40
# Not the correct instruction.
# Found jmp or nop at address: 42
# Changing code at address 42
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 46
# Not the correct instruction.
# Found jmp or nop at address: 49
# Changing code at address 49
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 50
# Changing code at address 50
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 51
# Changing code at address 51
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 52
# Not the correct instruction.
# Found jmp or nop at address: 53
# Not the correct instruction.
# Found jmp or nop at address: 54
# Not the correct instruction.
# Found jmp or nop at address: 55
# Not the correct instruction.
# Found jmp or nop at address: 56
# Changing code at address 56
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 57
# Changing code at address 57
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 59
# Not the correct instruction.
# Found jmp or nop at address: 61
# Not the correct instruction.
# Found jmp or nop at address: 62
# Not the correct instruction.
# Found jmp or nop at address: 66
# Not the correct instruction.
# Found jmp or nop at address: 70
# Not the correct instruction.
# Found jmp or nop at address: 72
# Not the correct instruction.
# Found jmp or nop at address: 77
# Not the correct instruction.
# Found jmp or nop at address: 78
# Changing code at address 78
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 79
# Not the correct instruction.
# Found jmp or nop at address: 80
# Not the correct instruction.
# Found jmp or nop at address: 82
# Not the correct instruction.
# Found jmp or nop at address: 83
# Not the correct instruction.
# Found jmp or nop at address: 86
# Not the correct instruction.
# Found jmp or nop at address: 88
# Not the correct instruction.
# Found jmp or nop at address: 91
# Not the correct instruction.
# Found jmp or nop at address: 92
# Not the correct instruction.
# Found jmp or nop at address: 94
# Changing code at address 94
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 96
# Changing code at address 96
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 97
# Changing code at address 97
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 98
# Not the correct instruction.
# Found jmp or nop at address: 99
# Changing code at address 99
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 101
# Changing code at address 101
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 103
# Not the correct instruction.
# Found jmp or nop at address: 106
# Not the correct instruction.
# Found jmp or nop at address: 109
# Changing code at address 109
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 110
# Not the correct instruction.
# Found jmp or nop at address: 111
# Not the correct instruction.
# Found jmp or nop at address: 112
# Not the correct instruction.
# Found jmp or nop at address: 114
# Not the correct instruction.
# Found jmp or nop at address: 117
# Not the correct instruction.
# Found jmp or nop at address: 121
# Not the correct instruction.
# Found jmp or nop at address: 124
# Changing code at address 124
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 126
# Not the correct instruction.
# Found jmp or nop at address: 130
# Changing code at address 130
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 133
# Not the correct instruction.
# Found jmp or nop at address: 134
# Not the correct instruction.
# Found jmp or nop at address: 135
# Not the correct instruction.
# Found jmp or nop at address: 136
# Not the correct instruction.
# Found jmp or nop at address: 139
# Not the correct instruction.
# Found jmp or nop at address: 141
# Not the correct instruction.
# Found jmp or nop at address: 143
# Changing code at address 143
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 145
# Changing code at address 145
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 146
# Not the correct instruction.
# Found jmp or nop at address: 149
# Changing code at address 149
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 150
# Not the correct instruction.
# Found jmp or nop at address: 153
# Not the correct instruction.
# Found jmp or nop at address: 154
# Changing code at address 154
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 156
# Not the correct instruction.
# Found jmp or nop at address: 157
# Changing code at address 157
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 160
# Not the correct instruction.
# Found jmp or nop at address: 162
# Not the correct instruction.
# Found jmp or nop at address: 163
# Changing code at address 163
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 167
# Changing code at address 167
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 172
# Not the correct instruction.
# Found jmp or nop at address: 176
# Changing code at address 176
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 177
# Not the correct instruction.
# Found jmp or nop at address: 178
# Not the correct instruction.
# Found jmp or nop at address: 182
# Changing code at address 182
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 184
# Not the correct instruction.
# Found jmp or nop at address: 186
# Not the correct instruction.
# Found jmp or nop at address: 187
# Not the correct instruction.
# Found jmp or nop at address: 189
# Changing code at address 189
# - Changin nop to jmp
# Not the correct instruction.
# Found jmp or nop at address: 190
# Changing code at address 190
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 195
# Not the correct instruction.
# Found jmp or nop at address: 199
# Not the correct instruction.
# Found jmp or nop at address: 200
# Not the correct instruction.
# Found jmp or nop at address: 201
# Not the correct instruction.
# Found jmp or nop at address: 204
# Changing code at address 204
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 205
# Not the correct instruction.
# Found jmp or nop at address: 207
# Changing code at address 207
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 209
# Changing code at address 209
# - Changing jmp to nop
# Not the correct instruction.
# Found jmp or nop at address: 210
# Changing code at address 210
# - Changing jmp to nop
# Found it! {'halted': True, 'program_counter': 623, 'accumulator': 2060}

# %%
with open('day8-list.txt', 'r') as file:
    content = file.read().splitlines()
    
def cleaning_data(item):
    list_operator = []
    for i in item:
        dict_operator = {}
        operator = i.split()
        dict_operator['code'] = operator[0]
        dict_operator['operand'] = int(operator[1])
        list_operator.append(dict_operator)
    return list_operator
list_of_instructions = cleaning_data(content)
i = 0
num = 0
while i < 6:
    if i in list_of_instructions:
        print('abc')
    else:
        print('vs')
    i += 1
# Out:
# vs
# vs
# vs
# vs
# vs
# vs

# %%
with open('day8-list.txt', 'r') as file:
    content = file.read().split('\n')
    content = [item.split() for item in content]


def make_dictionary(item):
    list_function = []
    for i, j in item:
        dict_function = {}
        keys = i
        value = j[1:]
        op = j[0]

        list_function.append({
            'operator': op,
            'value': int(value)
        })
        dict_function[keys] = list_function
    return dict_function
make_dictionary(content)
# Out:
# {'jmp': [{'operator': '+', 'value': 37},
#   {'operator': '-', 'value': 4},
#   {'operator': '+', 'value': 405},
#   {'operator': '+', 'value': 276},
#   {'operator': '+', 'value': 39},
#   {'operator': '+', 'value': 40},
#   {'operator': '-', 'value': 3},
#   {'operator': '+', 'value': 231},
#   {'operator': '+', 'value': 44},
#   {'operator': '+', 'value': 12},
#   {'operator': '+', 'value': 505},
#   {'operator': '+', 'value': 35},
#   {'operator': '+', 'value': 282},
#   {'operator': '+', 'value': 23},
#   {'operator': '+', 'value': 598},
#   {'operator': '+', 'value': 392},
#   {'operator': '+', 'value': 18},
#   {'operator': '+', 'value': 44},
#   {'operator': '+', 'value': 18},
#   {'operator': '+', 'value': 297},
#   {'operator': '+', 'value': 460},
#   {'operator': '+', 'value': 152},
#   {'operator': '+', 'value': 541},
#   {'operator': '+', 'value': 33},
#   {'operator': '-', 'value': 11},
#   {'operator': '-', 'value': 5},
#   {'operator': '+', 'value': 9},
#   {'operator': '+', 'value': 327},
#   {'operator': '+', 'value': 30},
#   {'operator': '-', 'value': 1},
#   {'operator': '-', 'value': 3},
#   {'operator': '+', 'value': 50},
#   {'operator': '+', 'value': 22},
#   {'operator': '+', 'value': 18},
#   {'operator': '+', 'value': 33},
#   {'operator': '+', 'value': 37},
#   {'operator': '+', 'value': 57},
#   {'operator': '-', 'value': 17},
#   {'operator': '-', 'value': 6},
#   {'operator': '-', 'value': 2},
#   {'operator': '+', 'value': 535},
#   {'operator': '-', 'value': 15},
#   {'operator': '+', 'value': 279},
#   {'operator': '+', 'value': 34},
#   {'operator': '+', 'value': 44},
#   {'operator': '+', 'value': 41},
#   {'operator': '+', 'value': 349},
#   {'operator': '+', 'value': 2},
#   {'operator': '+', 'value': 6},
#   {'operator': '+', 'value': 351},
#   {'operator': '+', 'value': 252},
#   {'operator': '+', 'value': 505},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 61},
#   {'operator': '+', 'value': 524},
#   {'operator': '+', 'value': 351},
#   {'operator': '+', 'value': 399},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 397},
#   {'operator': '+', 'value': 39},
#   {'operator': '+', 'value': 141},
#   {'operator': '+', 'value': 134},
#   {'operator': '+', 'value': 46},
#   {'operator': '+', 'value': 14},
#   {'operator': '+', 'value': 26},
#   {'operator': '+', 'value': 236},
#   {'operator': '+', 'value': 7},
#   {'operator': '-', 'value': 6},
#   {'operator': '+', 'value': 35},
#   {'operator': '+', 'value': 397},
#   {'operator': '+', 'value': 15},
#   {'operator': '+', 'value': 140},
#   {'operator': '+', 'value': 3},
#   {'operator': '-', 'value': 4},
#   {'operator': '+', 'value': 37},
#   {'operator': '+', 'value': 12},
#   {'operator': '+', 'value': 86},
#   {'operator': '+', 'value': 416},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 55},
#   {'operator': '-', 'value': 19},
#   {'operator': '+', 'value': 536},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 11},
#   {'operator': '+', 'value': 15},
#   {'operator': '-', 'value': 61},
#   {'operator': '+', 'value': 25},
#   {'operator': '-', 'value': 25},
#   {'operator': '+', 'value': 50},
#   {'operator': '+', 'value': 43},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 140},
#   {'operator': '+', 'value': 46},
#   {'operator': '-', 'value': 53},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 440},
#   {'operator': '+', 'value': 488},
#   {'operator': '+', 'value': 396},
#   {'operator': '+', 'value': 443},
#   {'operator': '+', 'value': 41},
#   {'operator': '+', 'value': 168},
#   {'operator': '+', 'value': 25},
#   {'operator': '+', 'value': 383},
#   {'operator': '+', 'value': 12},
#   {'operator': '-', 'value': 19},
#   {'operator': '+', 'value': 21},
#   {'operator': '+', 'value': 29},
#   {'operator': '+', 'value': 30},
#   {'operator': '+', 'value': 497},
#   {'operator': '+', 'value': 502},
#   {'operator': '+', 'value': 417},
#   {'operator': '+', 'value': 351},
#   {'operator': '-', 'value': 15},
#   {'operator': '+', 'value': 243},
#   {'operator': '+', 'value': 21},
#   {'operator': '+', 'value': 16},
#   {'operator': '+', 'value': 332},
#   {'operator': '+', 'value': 28},
#   {'operator': '+', 'value': 22},
#   {'operator': '+', 'value': 38},
#   {'operator': '+', 'value': 476},
#   {'operator': '+', 'value': 8},
#   {'operator': '-', 'value': 11},
#   {'operator': '+', 'value': 458},
#   {'operator': '+', 'value': 9},
#   {'operator': '+', 'value': 246},
#   {'operator': '+', 'value': 40},
#   {'operator': '+', 'value': 31},
#   {'operator': '+', 'value': 26},
#   {'operator': '+', 'value': 218},
#   {'operator': '+', 'value': 27},
#   {'operator': '+', 'value': 9},
#   {'operator': '+', 'value': 347},
#   {'operator': '+', 'value': 478},
#   {'operator': '+', 'value': 28},
#   {'operator': '+', 'value': 106},
#   {'operator': '+', 'value': 25},
#   {'operator': '-', 'value': 15},
#   {'operator': '+', 'value': 397},
#   {'operator': '+', 'value': 31},
#   {'operator': '+', 'value': 231},
#   {'operator': '-', 'value': 4},
#   {'operator': '+', 'value': 136},
#   {'operator': '+', 'value': 14},
#   {'operator': '+', 'value': 181},
#   {'operator': '+', 'value': 361},
#   {'operator': '+', 'value': 16},
#   {'operator': '+', 'value': 11},
#   {'operator': '-', 'value': 108},
#   {'operator': '+', 'value': 299},
#   {'operator': '+', 'value': 21},
#   {'operator': '-', 'value': 2},
#   {'operator': '-', 'value': 106},
#   {'operator': '+', 'value': 246},
#   {'operator': '+', 'value': 31},
#   {'operator': '+', 'value': 407},
#   {'operator': '+', 'value': 377},
#   {'operator': '+', 'value': 43},
#   {'operator': '-', 'value': 12},
#   {'operator': '+', 'value': 142},
#   {'operator': '+', 'value': 8},
#   {'operator': '-', 'value': 91},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 34},
#   {'operator': '+', 'value': 5},
#   {'operator': '+', 'value': 31},
#   {'operator': '+', 'value': 12},
#   {'operator': '+', 'value': 34},
#   {'operator': '+', 'value': 7},
#   {'operator': '+', 'value': 34},
#   {'operator': '+', 'value': 20},
#   {'operator': '-', 'value': 45},
#   {'operator': '-', 'value': 11},
#   {'operator': '+', 'value': 41},
#   {'operator': '+', 'value': 10},
#   {'operator': '+', 'value': 310},
#   {'operator': '-', 'value': 106},
#   {'operator': '-', 'value': 36},
#   {'operator': '+', 'value': 23},
#   {'operator': '+', 'value': 46},
#   {'operator': '+', 'value': 46},
#   {'operator': '+', 'value': 112},
#   {'operator': '+', 'value': 41},
#   {'operator': '+', 'value': 179},
#   {'operator': '+', 'value': 17},
#   {'operator': '+', 'value': 356},
#   {'operator': '+', 'value': 147},
#   {'operator': '+', 'value': 42},
#   {'operator': '+', 'value': 49},
#   {'operator': '+', 'value': 119},
#   {'operator': '+', 'value': 0},
#   {'operator': '+', 'value': 7},
#   {'operator': '-', 'value': 18},
#   {'operator': '-', 'value': 8},
#   {'operator': '+', 'value': 11},
#   {'operator': '+', 'value': 12},
#   {'operator': '+', 'value': 38},
#   {'operator': '+', 'value': 39},
#   {'operator': '+', 'value': 281},
#   {'operator': '+', 'value': 186},
#   {'operator': '+', 'value': 162},
#   {'operator': '+', 'value': 44},
#   {'operator': '+', 'value': 20},
#   {'operator': '+', 'value': 153},
#   {'operator': '+', 'value': 395},
#   {'operator': '+', 'value': 49},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 2},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 31},
#   {'operator': '+', 'value': 301},
#   {'operator': '+', 'value': 97},
#   {'operator': '-', 'value': 102},
#   {'operator': '+', 'value': 262},
#   {'operator': '+', 'value': 28},
#   {'operator': '-', 'value': 15},
#   {'operator': '+', 'value': 44},
#   {'operator': '-', 'value': 13},
#   {'operator': '+', 'value': 191},
#   {'operator': '+', 'value': 281},
#   {'operator': '+', 'value': 36},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 15},
#   {'operator': '+', 'value': 211},
#   {'operator': '+', 'value': 6},
#   {'operator': '-', 'value': 4},
#   {'operator': '+', 'value': 42},
#   {'operator': '+', 'value': 34},
#   {'operator': '+', 'value': 0},
#   {'operator': '+', 'value': 104},
#   {'operator': '+', 'value': 311},
#   {'operator': '+', 'value': 84},
#   {'operator': '+', 'value': 43},
#   {'operator': '-', 'value': 8},
#   {'operator': '-', 'value': 10},
#   {'operator': '+', 'value': 38},
#   {'operator': '-', 'value': 90},
#   {'operator': '+', 'value': 49},
#   {'operator': '+', 'value': 303},
#   {'operator': '+', 'value': 132},
#   {'operator': '+', 'value': 301},
#   {'operator': '+', 'value': 60},
#   {'operator': '+', 'value': 37},
#   {'operator': '+', 'value': 96},
#   {'operator': '+', 'value': 182},
#   {'operator': '+', 'value': 16},
#   {'operator': '+', 'value': 18},
#   {'operator': '+', 'value': 152},
#   {'operator': '+', 'value': 19},
#   {'operator': '+', 'value': 325},
#   {'operator': '-', 'value': 63},
#   {'operator': '+', 'value': 28},
#   {'operator': '+', 'value': 56},
#   {'operator': '+', 'value': 18},
#   {'operator': '+', 'value': 29},
#   {'operator': '+', 'value': 33},
#   {'operator': '-', 'value': 115},
#   {'operator': '+', 'value': 47},
#   {'operator': '+', 'value': 19},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 41},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 207},
#   {'operator': '-', 'value': 62},
#   {'operator': '-', 'value': 9},
#   {'operator': '+', 'value': 42},
#   {'operator': '-', 'value': 12},
#   {'operator': '-', 'value': 56},
#   {'operator': '+', 'value': 28},
#   {'operator': '-', 'value': 163},
#   {'operator': '+', 'value': 25},
#   {'operator': '+', 'value': 17},
#   {'operator': '-', 'value': 217},
#   {'operator': '+', 'value': 7},
#   {'operator': '+', 'value': 272},
#   {'operator': '+', 'value': 43},
#   {'operator': '+', 'value': 22},
#   {'operator': '+', 'value': 70},
#   {'operator': '-', 'value': 17},
#   {'operator': '-', 'value': 117},
#   {'operator': '+', 'value': 24},
#   {'operator': '+', 'value': 26},
#   {'operator': '-', 'value': 275},
#   {'operator': '-', 'value': 46},
#   {'operator': '+', 'value': 87},
#   {'operator': '+', 'value': 19},
#   {'operator': '+', 'value': 28},
#   {'operator': '-', 'value': 34},
#   {'operator': '+', 'value': 4},
#   {'operator': '+', 'value': 9},
#   {'operator': '+', 'value': 6},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 28},
#   {'operator': '-', 'value': 6},
#   {'operator': '-', 'value': 67},
#   {'operator': '-', 'value': 10},
#   {'operator': '+', 'value': 271},
#   {'operator': '+', 'value': 40},
#   {'operator': '+', 'value': 25},
#   {'operator': '-', 'value': 4},
#   {'operator': '-', 'value': 63},
#   {'operator': '+', 'value': 46},
#   {'operator': '+', 'value': 78},
#   {'operator': '+', 'value': 41},
#   {'operator': '-', 'value': 126},
#   {'operator': '+', 'value': 70},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 172},
#   {'operator': '+', 'value': 270},
#   {'operator': '+', 'value': 30},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 38},
#   {'operator': '+', 'value': 68},
#   {'operator': '+', 'value': 29},
#   {'operator': '+', 'value': 253},
#   {'operator': '-', 'value': 18},
#   {'operator': '-', 'value': 89},
#   {'operator': '+', 'value': 18},
#   {'operator': '+', 'value': 30},
#   {'operator': '+', 'value': 147},
#   {'operator': '+', 'value': 24},
#   {'operator': '+', 'value': 11},
#   {'operator': '+', 'value': 50},
#   {'operator': '-', 'value': 225},
#   {'operator': '-', 'value': 210},
#   {'operator': '-', 'value': 18},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 38},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 79},
#   {'operator': '+', 'value': 45},
#   {'operator': '+', 'value': 12},
#   {'operator': '+', 'value': 209},
#   {'operator': '-', 'value': 207},
#   {'operator': '+', 'value': 32},
#   {'operator': '+', 'value': 4},
#   {'operator': '+', 'value': 32},
#   {'operator': '+', 'value': 14},
#   {'operator': '+', 'value': 83},
#   {'operator': '+', 'value': 13},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 46},
#   {'operator': '+', 'value': 38},
#   {'operator': '+', 'value': 28},
#   {'operator': '+', 'value': 153},
#   {'operator': '-', 'value': 17},
#   {'operator': '-', 'value': 73},
#   {'operator': '+', 'value': 11},
#   {'operator': '+', 'value': 248},
#   {'operator': '+', 'value': 29},
#   {'operator': '+', 'value': 45},
#   {'operator': '+', 'value': 16},
#   {'operator': '+', 'value': 96},
#   {'operator': '-', 'value': 273},
#   {'operator': '+', 'value': 34},
#   {'operator': '+', 'value': 87},
#   {'operator': '+', 'value': 99},
#   {'operator': '-', 'value': 3},
#   {'operator': '-', 'value': 74},
#   {'operator': '+', 'value': 12},
#   {'operator': '-', 'value': 119},
#   {'operator': '-', 'value': 141},
#   {'operator': '-', 'value': 18},
#   {'operator': '-', 'value': 79},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 6},
#   {'operator': '+', 'value': 9},
#   {'operator': '+', 'value': 3},
#   {'operator': '+', 'value': 44},
#   {'operator': '+', 'value': 39},
#   {'operator': '-', 'value': 165},
#   {'operator': '+', 'value': 6},
#   {'operator': '+', 'value': 44},
#   {'operator': '+', 'value': 25},
#   {'operator': '-', 'value': 133},
#   {'operator': '+', 'value': 0},
#   {'operator': '+', 'value': 14},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 223},
#   {'operator': '+', 'value': 71},
#   {'operator': '-', 'value': 1},
#   {'operator': '+', 'value': 22},
#   {'operator': '+', 'value': 11},
#   {'operator': '-', 'value': 274},
#   {'operator': '-', 'value': 330},
#   {'operator': '+', 'value': 45},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 15},
#   {'operator': '-', 'value': 158},
#   {'operator': '-', 'value': 128},
#   {'operator': '+', 'value': 50},
#   {'operator': '+', 'value': 26},
#   {'operator': '-', 'value': 73},
#   {'operator': '+', 'value': 99},
#   {'operator': '+', 'value': 71},
#   {'operator': '+', 'value': 35},
#   {'operator': '+', 'value': 7},
#   {'operator': '+', 'value': 192},
#   {'operator': '+', 'value': 13},
#   {'operator': '+', 'value': 190},
#   {'operator': '+', 'value': 4},
#   {'operator': '-', 'value': 1},
#   {'operator': '+', 'value': 40},
#   {'operator': '-', 'value': 15},
#   {'operator': '+', 'value': 50},
#   {'operator': '+', 'value': 29},
#   {'operator': '-', 'value': 337},
#   {'operator': '-', 'value': 75},
#   {'operator': '+', 'value': 41},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 387},
#   {'operator': '+', 'value': 28},
#   {'operator': '+', 'value': 18},
#   {'operator': '+', 'value': 19},
#   {'operator': '-', 'value': 62},
#   {'operator': '-', 'value': 196},
#   {'operator': '-', 'value': 410},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 17},
#   {'operator': '-', 'value': 267},
#   {'operator': '+', 'value': 22},
#   {'operator': '-', 'value': 301},
#   {'operator': '-', 'value': 98},
#   {'operator': '-', 'value': 15},
#   {'operator': '-', 'value': 124},
#   {'operator': '+', 'value': 45},
#   {'operator': '-', 'value': 18},
#   {'operator': '+', 'value': 15},
#   {'operator': '+', 'value': 42},
#   {'operator': '-', 'value': 296},
#   {'operator': '-', 'value': 10},
#   {'operator': '+', 'value': 29},
#   {'operator': '-', 'value': 371},
#   {'operator': '+', 'value': 3},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 61},
#   {'operator': '+', 'value': 5},
#   {'operator': '-', 'value': 361},
#   {'operator': '-', 'value': 5},
#   {'operator': '-', 'value': 326},
#   {'operator': '-', 'value': 379},
#   {'operator': '-', 'value': 10},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 44},
#   {'operator': '-', 'value': 231},
#   {'operator': '+', 'value': 3},
#   {'operator': '-', 'value': 94},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 113},
#   {'operator': '-', 'value': 336},
#   {'operator': '+', 'value': 4},
#   {'operator': '-', 'value': 299},
#   {'operator': '-', 'value': 13},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 13},
#   {'operator': '+', 'value': 143},
#   {'operator': '-', 'value': 11},
#   {'operator': '-', 'value': 19},
#   {'operator': '+', 'value': 18},
#   {'operator': '-', 'value': 390},
#   {'operator': '-', 'value': 27},
#   {'operator': '+', 'value': 42},
#   {'operator': '-', 'value': 232},
#   {'operator': '+', 'value': 15},
#   {'operator': '-', 'value': 228},
#   {'operator': '+', 'value': 21},
#   {'operator': '+', 'value': 39},
#   {'operator': '+', 'value': 47},
#   {'operator': '+', 'value': 6},
#   {'operator': '+', 'value': 57},
#   {'operator': '+', 'value': 28},
#   {'operator': '+', 'value': 27},
#   {'operator': '+', 'value': 50},
#   {'operator': '-', 'value': 397},
#   {'operator': '+', 'value': 12},
#   {'operator': '-', 'value': 445},
#   {'operator': '+', 'value': 30},
#   {'operator': '-', 'value': 352},
#   {'operator': '-', 'value': 4},
#   {'operator': '+', 'value': 26},
#   {'operator': '+', 'value': 48},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 205},
#   {'operator': '+', 'value': 22},
#   {'operator': '-', 'value': 284},
#   {'operator': '-', 'value': 1},
#   {'operator': '-', 'value': 361},
#   {'operator': '+', 'value': 0},
#   {'operator': '-', 'value': 368},
#   {'operator': '-', 'value': 17},
#   {'operator': '-', 'value': 223},
#   {'operator': '-', 'value': 41},
#   {'operator': '+', 'value': 4},
#   {'operator': '+', 'value': 46},
#   {'operator': '+', 'value': 79},
#   {'operator': '-', 'value': 370},
#   {'operator': '-', 'value': 260},
#   {'operator': '+', 'value': 42},
#   {'operator': '-', 'value': 14},
#   {'operator': '+', 'value': 30},
#   {'operator': '+', 'value': 50},
#   {'operator': '+', 'value': 13},
#   {'operator': '-', 'value': 61},
#   {'operator': '+', 'value': 46},
#   {'operator': '-', 'value': 63},
#   {'operator': '-', 'value': 55},
#   {'operator': '-', 'value': 320},
#   {'operator': '-', 'value': 11},
#   {'operator': '+', 'value': 10},
#   {'operator': '-', 'value': 424},
#   {'operator': '-', 'value': 11},
#   {'operator': '+', 'value': 3},
#   {'operator': '-', 'value': 71},
#   {'operator': '+', 'value': 42},
#   {'operator': '-', 'value': 13},
#   {'operator': '+', 'value': 4},
#   {'operator': '-', 'value': 155},
#   {'operator': '-', 'value': 138},
#   {'operator': '+', 'value': 62},
#   {'operator': '+', 'value': 11},
#   {'operator': '+', 'value': 19},
#   {'operator': '+', 'value': 15},
#   {'operator': '+', 'value': 17},
#   {'operator': '-', 'value': 73},
#   {'operator': '-', 'value': 11},
#   {'operator': '-', 'value': 273},
#   {'operator': '+', 'value': 8},
#   {'operator': '+', 'value': 6},
#   {'operator': '-', 'value': 7},
#   {'operator': '+', 'value': 41},
#   {'operator': '-', 'value': 311},
#   {'operator': '-', 'value': 111},
#   {'operator': '-', 'value': 260},
#   {'operator': '+', 'value': 50},
#   {'operator': '-', 'value': 60},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 89},
#   {'operator': '+', 'value': 36},
#   {'operator': '+', 'value': 14},
#   {'operator': '-', 'value': 220},
#   {'operator': '-', 'value': 415},
#   {'operator': '+', 'value': 28},
#   {'operator': '-', 'value': 402},
#   {'operator': '+', 'value': 41},
#   {'operator': '-', 'value': 165},
#   {'operator': '+', 'value': 9},
#   {'operator': '-', 'value': 13},
#   {'operator': '-', 'value': 18},
#   {'operator': '+', 'value': 18},
#   {'operator': '-', 'value': 504},
#   {'operator': '-', 'value': 9},
#   {'operator': '+', 'value': 29},
#   {'operator': '+', 'value': 44},
#   {'operator': '-', 'value': 444},
#   {'operator': '+', 'value': 5},
#   {'operator': '+', 'value': 47},
#   {'operator': '-', 'value': 545},
#   {'operator': '+', 'value': 23},
#   {'operator': '+', 'value': 7},
#   {'operator': '-', 'value': 240},
#   {'operator': '-', 'value': 320},
#   {'operator': '-', 'value': 141},
#   {'operator': '+', 'value': 1},
#   {'operator': '+', 'value': 28},
#   {'operator': '-', 'value': 287},
#   {'operator': '-', 'value': 118},
#   {'operator': '+', 'value': 44},
#   {'operator': '-', 'value': 7},
#   {'operator': '-', 'value': 550},
#   {'operator': '+', 'value': 10},
#   {'operator': '+', 'value': 20},
#   {'operator': '-', 'value': 3},
#   {'operator': '-', 'value': 401},
#   {'operator': '+', 'value': 45},
#   {'operator': '+', 'value': 36},
#   {'operator': '-', 'value': 375},
#   {'operator': '-', 'value': 485},
#   {'operator': '+', 'value': 9},
#   {'operator': '-', 'value': 338},
#   {'operator': '-', 'value': 510},
#   {'operator': '-', 'value': 196},
#   {'operator': '-', 'value': 16},
#   {'operator': '-', 'value': 372},
#   {'operator': '+', 'value': 0},
#   {'operator': '-', 'value': 380},
#   {'operator': '-', 'value': 3},
#   {'operator': '-', 'value': 473},
#   {'operator': '-', 'value': 361},
#   {'operator': '-', 'value': 311},
#   {'operator': '+', 'value': 0},
#   {'operator': '+', 'value': 20},
#   {'operator': '-', 'value': 436},
#   {'operator': '+', 'value': 9},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 215},
#   {'operator': '+', 'value': 19},
#   {'operator': '-', 'value': 451},
#   {'operator': '-', 'value': 43},
#   {'operator': '-', 'value': 13},
#   {'operator': '-', 'value': 10},
#   {'operator': '-', 'value': 5},
#   {'operator': '-', 'value': 208},
#   {'operator': '-', 'value': 11},
#   {'operator': '-', 'value': 156},
#   {'operator': '+', 'value': 11},
#   {'operator': '-', 'value': 2},
#   {'operator': '-', 'value': 357},
#   {'operator': '-', 'value': 73},
#   {'operator': '+', 'value': 21},
#   {'operator': '-', 'value': 159},
#   {'operator': '+', 'value': 28},
#   {'operator': '-', 'value': 16},
#   {'operator': '+', 'value': 12},
#   {'operator': '+', 'value': 1},
#   {'operator': '-', 'value': 282},
#   {'operator': '-', 'value': 131},
#   {'operator': '-', 'value': 11},
#   {'operator': '+', 'value': 45},
#   {'operator': '+', 'value': 0},
#   {'operator': '+', 'value': 28},
#   {'operator': '+', 'value': 1}]}

# %%
with open('day8-list.txt', 'r') as file:
    content = file.read().splitlines()
def cleaning_data(item):
    list_operator = []
    for i in item:
        dict_operator = {}
        operator = i.split()
        dict_operator['code'] = operator[0]
        dict_operator['operand'] = int(operator[1])
        list_operator.append(dict_operator)
    return list_operator
list_of_instructions = cleaning_data(content)
print(content)
# Out:
# ['acc +37', 'acc -4', 'nop +405', 'jmp +276', 'acc +39', 'acc +40', 'acc -3', 'jmp +231', 'acc +44', 'acc +12', 'jmp +505', 'acc +35', 'jmp +282', 'acc +23', 'jmp +598', 'nop +392', 'acc +18', 'acc +44', 'acc +18', 'jmp +297', 'nop +460', 'jmp +152', 'nop +541', 'acc +33', 'jmp -11', 'acc -5', 'acc +9', 'jmp +327', 'acc +30', 'acc -1', 'acc -3', 'jmp +50', 'acc +22', 'acc +18', 'acc +33', 'acc +37', 'jmp +57', 'acc -17', 'acc -6', 'acc -2', 'jmp +535', 'acc -15', 'jmp +279', 'acc +34', 'acc +44', 'acc +41', 'jmp +349', 'acc +2', 'acc +6', 'nop +351', 'nop +252', 'jmp +505', 'jmp +1', 'jmp +1', 'nop +61', 'jmp +524', 'nop +351', 'jmp +399', 'acc +1', 'nop +397', 'acc +39', 'nop +141', 'jmp +134', 'acc +46', 'acc +14', 'acc +26', 'jmp +236', 'acc +7', 'acc -6', 'acc +35', 'jmp +397', 'acc +15', 'jmp +140', 'acc +3', 'acc -4', 'acc +37', 'acc +12', 'jmp +86', 'jmp +416', 'jmp +1', 'jmp +55', 'acc -19', 'jmp +536', 'jmp +1', 'acc -11', 'acc +15', 'jmp -61', 'acc +25', 'jmp -25', 'acc +50', 'acc +43', 'jmp +1', 'jmp +140', 'acc +46', 'nop -53', 'acc +1', 'nop +440', 'jmp +488', 'jmp +396', 'nop +443', 'acc +41', 'jmp +168', 'acc +25', 'nop +383', 'acc +12', 'acc -19', 'jmp +21', 'acc +29', 'acc +30', 'jmp +497', 'jmp +502', 'jmp +417', 'nop +351', 'acc -15', 'jmp +243', 'acc +21', 'acc +16', 'jmp +332', 'acc +28', 'acc +22', 'acc +38', 'jmp +476', 'acc +8', 'acc -11', 'jmp +458', 'acc +9', 'jmp +246', 'acc +40', 'acc +31', 'acc +26', 'jmp +218', 'acc +27', 'acc +9', 'nop +347', 'jmp +478', 'nop +28', 'nop +106', 'acc +25', 'acc -15', 'jmp +397', 'acc +31', 'jmp +231', 'acc -4', 'nop +136', 'acc +14', 'jmp +181', 'jmp +361', 'acc +16', 'acc +11', 'jmp -108', 'nop +299', 'acc +21', 'acc -2', 'jmp -106', 'jmp +246', 'acc +31', 'jmp +407', 'jmp +377', 'acc +43', 'acc -12', 'nop +142', 'acc +8', 'jmp -91', 'jmp +1', 'acc +34', 'acc +5', 'acc +31', 'jmp +12', 'acc +34', 'acc +7', 'acc +34', 'acc +20', 'jmp -45', 'acc -11', 'acc +41', 'acc +10', 'jmp +310', 'nop -106', 'jmp -36', 'acc +23', 'acc +46', 'acc +46', 'jmp +112', 'acc +41', 'nop +179', 'acc +17', 'nop +356', 'jmp +147', 'acc +42', 'nop +49', 'jmp +119', 'acc +0', 'acc +7', 'acc -18', 'acc -8', 'jmp +11', 'acc +12', 'acc +38', 'acc +39', 'jmp +281', 'nop +186', 'jmp +162', 'acc +44', 'acc +20', 'jmp +153', 'jmp +395', 'acc +49', 'jmp +1', 'acc +2', 'jmp +1', 'jmp -31', 'jmp +301', 'nop +97', 'jmp -102', 'jmp +262', 'acc +28', 'acc -15', 'acc +44', 'acc -13', 'jmp +191', 'jmp +281', 'acc +36', 'acc +1', 'nop +15', 'jmp +211', 'acc +6', 'acc -4', 'jmp +42', 'acc +34', 'acc +0', 'jmp +104', 'jmp +311', 'jmp +84', 'acc +43', 'acc -8', 'acc -10', 'acc +38', 'jmp -90', 'acc +49', 'jmp +303', 'nop +132', 'jmp +301', 'nop +60', 'acc +37', 'nop +96', 'jmp +182', 'acc +16', 'acc +18', 'nop +152', 'acc +19', 'jmp +325', 'jmp -63', 'acc +28', 'jmp +56', 'acc +18', 'acc +29', 'acc +33', 'jmp -115', 'acc +47', 'acc +19', 'jmp +1', 'nop +41', 'jmp +1', 'jmp -207', 'nop -62', 'acc -9', 'acc +42', 'acc -12', 'jmp -56', 'acc +28', 'jmp -163', 'acc +25', 'acc +17', 'jmp -217', 'acc +7', 'jmp +272', 'acc +43', 'acc +22', 'jmp +70', 'acc -17', 'jmp -117', 'acc +24', 'acc +26', 'nop -275', 'jmp -46', 'nop +87', 'acc +19', 'acc +28', 'jmp -34', 'acc +4', 'acc +9', 'acc +6', 'jmp +1', 'jmp +28', 'acc -6', 'nop -67', 'acc -10', 'jmp +271', 'acc +40', 'acc +25', 'acc -4', 'jmp -63', 'acc +46', 'jmp +78', 'acc +41', 'nop -126', 'nop +70', 'jmp +1', 'jmp +172', 'nop +270', 'jmp +30', 'jmp +1', 'acc +38', 'nop +68', 'acc +29', 'jmp +253', 'acc -18', 'jmp -89', 'acc +18', 'acc +30', 'jmp +147', 'acc +24', 'acc +11', 'acc +50', 'jmp -225', 'jmp -210', 'acc -18', 'acc +1', 'acc +38', 'jmp +1', 'jmp -79', 'acc +45', 'acc +12', 'jmp +209', 'jmp -207', 'acc +32', 'acc +4', 'acc +32', 'acc +14', 'jmp +83', 'acc +13', 'acc +1', 'acc +46', 'acc +38', 'jmp +28', 'nop +153', 'acc -17', 'jmp -73', 'acc +11', 'jmp +248', 'acc +29', 'acc +45', 'acc +16', 'jmp +96', 'jmp -273', 'acc +34', 'jmp +87', 'nop +99', 'acc -3', ' ...
